# %%
import json
import pandas as pd
import glob

# Directory containing all JSON files
json_files = glob.glob("C:\\Users\\HP\\Downloads\\ipl_male_json (1)\\*.json")

# Initialize an empty DataFrame to store all matches' data
all_matches_df = pd.DataFrame()

# Process each JSON file
for file in json_files:
    with open(file, 'r') as f:
        data = json.load(f)

    # Extract innings data and check if there are two innings
    innings = data.get('innings', [])
    if len(innings) < 2:
        # Skip files with fewer than two innings
        continue

    total_runs = None
    match_df = pd.DataFrame()

    # First inning to get target
    first_inning = innings[0]
    total_runs = sum(delivery['runs']['total'] for over in first_inning['overs'] for delivery in over['deliveries'])
    target = total_runs + 1

    # Process the second inning (chasing)
    second_inning = innings[1]
    batting_team = second_inning['team']
    bowling_team = first_inning['team']
    
    balls_left = 120  # Assuming T20 match, 20 overs * 6 balls
    wickets_left = 10
    cumulative_runs = 0

    rows = []  # List to accumulate rows before converting to DataFrame

    for over in second_inning['overs']:
        for delivery in over['deliveries']:
            balls_left -= 1
            
            # Runs scored on this delivery
            runs_scored = delivery['runs']['total']
            cumulative_runs += runs_scored
            
            # Check for wicket
            if 'wickets' in delivery:
                wickets_left -= len(delivery['wickets'])
            
            # Calculate columns
            runs_left = target - cumulative_runs
            crr = (cumulative_runs / ((120 - balls_left) / 6)) if balls_left < 120 else 0
            rrr = (runs_left / (balls_left / 6)) if balls_left > 0 else 0
            
            # Set result to 1 or 0 based on winner; default to None if 'winner' is missing
            result = 1 if data['info'].get('outcome', {}).get('winner') == batting_team else 0

            # Append data for each ball as a dictionary in the rows list
            rows.append({
                'batting_team': batting_team,
                'bowling_team': bowling_team,
                'runs_left': runs_left,
                'balls_left': balls_left,
                'wickets_left': wickets_left,
                'total_runs': total_runs,
                'target': target,
                'crr': crr,
                'rrr': rrr,
                'result': result
            })

    # Convert rows to a DataFrame and then concatenate to match_df
    match_df = pd.DataFrame(rows)
    all_matches_df = pd.concat([all_matches_df, match_df], ignore_index=True)

# Display the first few rows of the final DataFrame
all_matches_df.head()
# Out:
#                   batting_team         bowling_team  runs_left  balls_left  \
# 0  Royal Challengers Bangalore  Sunrisers Hyderabad        207         119
# 1  Royal Challengers Bangalore  Sunrisers Hyderabad        207         118
# 2  Royal Challengers Bangalore  Sunrisers Hyderabad        207         117
# 3  Royal Challengers Bangalore  Sunrisers Hyderabad        205         116
# 4  Royal Challengers Bangalore  Sunrisers Hyderabad        201         115
#
#    wickets_left  total_runs  target  crr        rrr  result
# 0            10         207     208  6.0  10.436975       0
# 1            10         207     208  3.0  10.525424       0
# 2            10         207     208  2.0  10.615385       0
# 3            10         207     208  4.5  10.603448       0
# 4            10         207     208  8.4  10.486957       0

# %%
all_matches_df.tail()
# Out:
#                        batting_team         bowling_team  runs_left  \
# 125736  Royal Challengers Bangalore  Sunrisers Hyderabad         15
# 125737  Royal Challengers Bangalore  Sunrisers Hyderabad         15
# 125738  Royal Challengers Bangalore  Sunrisers Hyderabad         14
# 125739  Royal Challengers Bangalore  Sunrisers Hyderabad         13
# 125740  Royal Challengers Bangalore  Sunrisers Hyderabad          9
#
#         balls_left  wickets_left  total_runs  target       crr  rrr  result
# 125736           0             4         208     209  9.700000  0.0       0
# 125737          -1             3         208     209  9.619835  0.0       0
# 125738          -2             3         208     209  9.590164  0.0       0
# 125739          -3             3         208     209  9.560976  0.0       0
# 125740          -4             3         208     209  9.677419  0.0       0

# %%
all_matches_df.shape
# Out:
# (125741, 10)

# %%
json_files = glob.glob("C:\\Users\\HP\\Downloads\\ipl_male_json (1)\\*.json")
print(f"Total files found: {len(json_files)}")
# Out:
# Total files found: 1095

# %%
print(f"Total files found: {len(json_files)}")
total_rows = 0
for file in json_files:
    # Process each file
    with open(file, 'r') as f:
        data = json.load(f)
    # Skip files with fewer than two innings
    innings = data.get('innings', [])
    if len(innings) < 2:
        continue

    # Process inning data (existing code)
    match_df = pd.DataFrame(rows)
    rows_count = len(match_df)
    total_rows += rows_count
    print(f"File: {file}, Rows added: {rows_count}, Total rows: {total_rows}")
    
    # Add match data to all_matches_df
    all_matches_df = pd.concat([all_matches_df, match_df], ignore_index=True)
# Out:
# Total files found: 1095
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082591.json, Rows added: 124, Total rows: 124
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082592.json, Rows added: 124, Total rows: 248
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082593.json, Rows added: 124, Total rows: 372
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082594.json, Rows added: 124, Total rows: 496
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082595.json, Rows added: 124, Total rows: 620
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082596.json, Rows added: 124, Total rows: 744
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082597.json, Rows added: 124, Total rows: 868
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082598.json, Rows added: 124, Total rows: 992
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082599.json, Rows added: 124, Total rows: 1116
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082600.json, Rows added: 124, Total rows: 1240
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082601.json, Rows added: 124, Total rows: 1364
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082602.json, Rows added: 124, Total rows: 1488
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082603.json, Rows added: 124, Total rows: 1612
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082604.json, Rows added: 124, Total rows: 1736
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082605.json, Rows added: 124, Total rows: 1860
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082606.json, Rows added: 124, Total rows: 1984
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082607.json, Rows added: 124, Total rows: 2108
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082608.json, Rows added: 124, Total rows: 2232
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082609.json, Rows added: 124, Total rows: 2356
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082610.json, Rows added: 124, Total rows: 2480
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082611.json, Rows added: 124, Total rows: 2604
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082612.json, Rows added: 124, Total rows: 2728
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082613.json, Rows added: 124, Total rows: 2852
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082614.json, Rows added: 124, Total rows: 2976
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082615.json, Rows added: 124, Total rows: 3100
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082616.json, Rows added: 124, Total rows: 3224
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082617.json, Rows added: 124, Total rows: 3348
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082618.json, Rows added: 124, Total rows: 3472
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082620.json, Rows added: 124, Total rows: 3596
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082621.json, Rows added: 124, Total rows: 3720
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082622.json, Rows added: 124, Total rows: 3844
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082623.json, Rows added: 124, Total rows: 3968
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082624.json, Rows added: 124, Total rows: 4092
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082625.json, Rows added: 124, Total rows: 4216
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082626.json, Rows added: 124, Total rows: 4340
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082627.json, Rows added: 124, Total rows: 4464
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082628.json, Rows added: 124, Total rows: 4588
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082629.json, Rows added: 124, Total rows: 4712
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082630.json, Rows added: 124, Total rows: 4836
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082631.json, Rows added: 124, Total rows: 4960
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082632.json, Rows added: 124, Total rows: 5084
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082633.json, Rows added: 124, Total rows: 5208
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082634.json, Rows added: 124, Total rows: 5332
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082635.json, Rows added: 124, Total rows: 5456
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082636.json, Rows added: 124, Total rows: 5580
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082637.json, Rows added: 124, Total rows: 5704
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082638.json, Rows added: 124, Total rows: 5828
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082639.json, Rows added: 124, Total rows: 5952
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082640.json, Rows added: 124, Total rows: 6076
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082641.json, Rows added: 124, Total rows: 6200
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082642.json, Rows added: 124, Total rows: 6324
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082643.json, Rows added: 124, Total rows: 6448
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082644.json, Rows added: 124, Total rows: 6572
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082645.json, Rows added: 124, Total rows: 6696
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082646.json, Rows added: 124, Total rows: 6820
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082647.json, Rows added: 124, Total rows: 6944
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082648.json, Rows added: 124, Total rows: 7068
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082649.json, Rows added: 124, Total rows: 7192
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1082650.json, Rows added: 124, Total rows: 7316
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136561.json, Rows added: 124, Total rows: 7440
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136562.json, Rows added: 124, Total rows: 7564
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136563.json, Rows added: 124, Total rows: 7688
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136564.json, Rows added: 124, Total rows: 7812
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136565.json, Rows added: 124, Total rows: 7936
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136566.json, Rows added: 124, Total rows: 8060
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136567.json, Rows added: 124, Total rows: 8184
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136568.json, Rows added: 124, Total rows: 8308
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136569.json, Rows added: 124, Total rows: 8432
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136570.json, Rows added: 124, Total rows: 8556
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136571.json, Rows added: 124, Total rows: 8680
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136572.json, Rows added: 124, Total rows: 8804
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136573.json, Rows added: 124, Total rows: 8928
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136574.json, Rows added: 124, Total rows: 9052
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136575.json, Rows added: 124, Total rows: 9176
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136576.json, Rows added: 124, Total rows: 9300
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136577.json, Rows added: 124, Total rows: 9424
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136578.json, Rows added: 124, Total rows: 9548
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136579.json, Rows added: 124, Total rows: 9672
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136580.json, Rows added: 124, Total rows: 9796
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136581.json, Rows added: 124, Total rows: 9920
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136582.json, Rows added: 124, Total rows: 10044
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136583.json, Rows added: 124, Total rows: 10168
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136584.json, Rows added: 124, Total rows: 10292
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136585.json, Rows added: 124, Total rows: 10416
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136586.json, Rows added: 124, Total rows: 10540
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136587.json, Rows added: 124, Total rows: 10664
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136588.json, Rows added: 124, Total rows: 10788
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136589.json, Rows added: 124, Total rows: 10912
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136590.json, Rows added: 124, Total rows: 11036
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136591.json, Rows added: 124, Total rows: 11160
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136592.json, Rows added: 124, Total rows: 11284
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136593.json, Rows added: 124, Total rows: 11408
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136594.json, Rows added: 124, Total rows: 11532
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136595.json, Rows added: 124, Total rows: 11656
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136596.json, Rows added: 124, Total rows: 11780
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136597.json, Rows added: 124, Total rows: 11904
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136598.json, Rows added: 124, Total rows: 12028
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136599.json, Rows added: 124, Total rows: 12152
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136600.json, Rows added: 124, Total rows: 12276
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136601.json, Rows added: 124, Total rows: 12400
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136602.json, Rows added: 124, Total rows: 12524
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136603.json, Rows added: 124, Total rows: 12648
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136604.json, Rows added: 124, Total rows: 12772
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136605.json, Rows added: 124, Total rows: 12896
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136606.json, Rows added: 124, Total rows: 13020
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136607.json, Rows added: 124, Total rows: 13144
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136608.json, Rows added: 124, Total rows: 13268
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136609.json, Rows added: 124, Total rows: 13392
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136610.json, Rows added: 124, Total rows: 13516
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136611.json, Rows added: 124, Total rows: 13640
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136612.json, Rows added: 124, Total rows: 13764
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136613.json, Rows added: 124, Total rows: 13888
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136614.json, Rows added: 124, Total rows: 14012
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136615.json, Rows added: 124, Total rows: 14136
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136616.json, Rows added: 124, Total rows: 14260
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136617.json, Rows added: 124, Total rows: 14384
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136618.json, Rows added: 124, Total rows: 14508
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136619.json, Rows added: 124, Total rows: 14632
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1136620.json, Rows added: 124, Total rows: 14756
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175356.json, Rows added: 124, Total rows: 14880
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175357.json, Rows added: 124, Total rows: 15004
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175358.json, Rows added: 124, Total rows: 15128
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175359.json, Rows added: 124, Total rows: 15252
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175360.json, Rows added: 124, Total rows: 15376
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175361.json, Rows added: 124, Total rows: 15500
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175362.json, Rows added: 124, Total rows: 15624
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175363.json, Rows added: 124, Total rows: 15748
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175364.json, Rows added: 124, Total rows: 15872
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175365.json, Rows added: 124, Total rows: 15996
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175366.json, Rows added: 124, Total rows: 16120
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175367.json, Rows added: 124, Total rows: 16244
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175368.json, Rows added: 124, Total rows: 16368
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175369.json, Rows added: 124, Total rows: 16492
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175370.json, Rows added: 124, Total rows: 16616
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175371.json, Rows added: 124, Total rows: 16740
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1175372.json, Rows added: 124, Total rows: 16864
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178393.json, Rows added: 124, Total rows: 16988
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178394.json, Rows added: 124, Total rows: 17112
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178395.json, Rows added: 124, Total rows: 17236
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178396.json, Rows added: 124, Total rows: 17360
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178397.json, Rows added: 124, Total rows: 17484
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178398.json, Rows added: 124, Total rows: 17608
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178399.json, Rows added: 124, Total rows: 17732
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178400.json, Rows added: 124, Total rows: 17856
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178401.json, Rows added: 124, Total rows: 17980
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178402.json, Rows added: 124, Total rows: 18104
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178403.json, Rows added: 124, Total rows: 18228
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178404.json, Rows added: 124, Total rows: 18352
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178405.json, Rows added: 124, Total rows: 18476
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178406.json, Rows added: 124, Total rows: 18600
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178407.json, Rows added: 124, Total rows: 18724
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178408.json, Rows added: 124, Total rows: 18848
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178409.json, Rows added: 124, Total rows: 18972
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178410.json, Rows added: 124, Total rows: 19096
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178411.json, Rows added: 124, Total rows: 19220
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178412.json, Rows added: 124, Total rows: 19344
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178413.json, Rows added: 124, Total rows: 19468
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178414.json, Rows added: 124, Total rows: 19592
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178415.json, Rows added: 124, Total rows: 19716
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178416.json, Rows added: 124, Total rows: 19840
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178417.json, Rows added: 124, Total rows: 19964
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178418.json, Rows added: 124, Total rows: 20088
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178419.json, Rows added: 124, Total rows: 20212
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178420.json, Rows added: 124, Total rows: 20336
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178421.json, Rows added: 124, Total rows: 20460
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178422.json, Rows added: 124, Total rows: 20584
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178423.json, Rows added: 124, Total rows: 20708
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178424.json, Rows added: 124, Total rows: 20832
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178425.json, Rows added: 124, Total rows: 20956
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178426.json, Rows added: 124, Total rows: 21080
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178427.json, Rows added: 124, Total rows: 21204
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178428.json, Rows added: 124, Total rows: 21328
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178429.json, Rows added: 124, Total rows: 21452
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178430.json, Rows added: 124, Total rows: 21576
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1178431.json, Rows added: 124, Total rows: 21700
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1181764.json, Rows added: 124, Total rows: 21824
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1181766.json, Rows added: 124, Total rows: 21948
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1181767.json, Rows added: 124, Total rows: 22072
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1181768.json, Rows added: 124, Total rows: 22196
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216492.json, Rows added: 124, Total rows: 22320
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216493.json, Rows added: 124, Total rows: 22444
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216494.json, Rows added: 124, Total rows: 22568
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216495.json, Rows added: 124, Total rows: 22692
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216496.json, Rows added: 124, Total rows: 22816
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216497.json, Rows added: 124, Total rows: 22940
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216498.json, Rows added: 124, Total rows: 23064
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216499.json, Rows added: 124, Total rows: 23188
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216500.json, Rows added: 124, Total rows: 23312
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216501.json, Rows added: 124, Total rows: 23436
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216502.json, Rows added: 124, Total rows: 23560
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216503.json, Rows added: 124, Total rows: 23684
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216504.json, Rows added: 124, Total rows: 23808
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216505.json, Rows added: 124, Total rows: 23932
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216506.json, Rows added: 124, Total rows: 24056
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216507.json, Rows added: 124, Total rows: 24180
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216508.json, Rows added: 124, Total rows: 24304
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216509.json, Rows added: 124, Total rows: 24428
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216510.json, Rows added: 124, Total rows: 24552
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216511.json, Rows added: 124, Total rows: 24676
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216512.json, Rows added: 124, Total rows: 24800
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216513.json, Rows added: 124, Total rows: 24924
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216514.json, Rows added: 124, Total rows: 25048
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216515.json, Rows added: 124, Total rows: 25172
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216516.json, Rows added: 124, Total rows: 25296
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216517.json, Rows added: 124, Total rows: 25420
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216518.json, Rows added: 124, Total rows: 25544
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216519.json, Rows added: 124, Total rows: 25668
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216520.json, Rows added: 124, Total rows: 25792
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216521.json, Rows added: 124, Total rows: 25916
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216522.json, Rows added: 124, Total rows: 26040
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216523.json, Rows added: 124, Total rows: 26164
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216524.json, Rows added: 124, Total rows: 26288
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216525.json, Rows added: 124, Total rows: 26412
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216526.json, Rows added: 124, Total rows: 26536
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216527.json, Rows added: 124, Total rows: 26660
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216528.json, Rows added: 124, Total rows: 26784
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216529.json, Rows added: 124, Total rows: 26908
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216530.json, Rows added: 124, Total rows: 27032
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216531.json, Rows added: 124, Total rows: 27156
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216532.json, Rows added: 124, Total rows: 27280
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216533.json, Rows added: 124, Total rows: 27404
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216534.json, Rows added: 124, Total rows: 27528
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216535.json, Rows added: 124, Total rows: 27652
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216536.json, Rows added: 124, Total rows: 27776
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216537.json, Rows added: 124, Total rows: 27900
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216538.json, Rows added: 124, Total rows: 28024
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216539.json, Rows added: 124, Total rows: 28148
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216540.json, Rows added: 124, Total rows: 28272
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216541.json, Rows added: 124, Total rows: 28396
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216542.json, Rows added: 124, Total rows: 28520
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216543.json, Rows added: 124, Total rows: 28644
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216544.json, Rows added: 124, Total rows: 28768
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216545.json, Rows added: 124, Total rows: 28892
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216546.json, Rows added: 124, Total rows: 29016
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1216547.json, Rows added: 124, Total rows: 29140
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1237177.json, Rows added: 124, Total rows: 29264
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1237178.json, Rows added: 124, Total rows: 29388
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1237180.json, Rows added: 124, Total rows: 29512
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1237181.json, Rows added: 124, Total rows: 29636
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254058.json, Rows added: 124, Total rows: 29760
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254059.json, Rows added: 124, Total rows: 29884
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254060.json, Rows added: 124, Total rows: 30008
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254061.json, Rows added: 124, Total rows: 30132
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254062.json, Rows added: 124, Total rows: 30256
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254063.json, Rows added: 124, Total rows: 30380
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254064.json, Rows added: 124, Total rows: 30504
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254065.json, Rows added: 124, Total rows: 30628
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254066.json, Rows added: 124, Total rows: 30752
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254067.json, Rows added: 124, Total rows: 30876
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254068.json, Rows added: 124, Total rows: 31000
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254069.json, Rows added: 124, Total rows: 31124
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254070.json, Rows added: 124, Total rows: 31248
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254071.json, Rows added: 124, Total rows: 31372
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254072.json, Rows added: 124, Total rows: 31496
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254073.json, Rows added: 124, Total rows: 31620
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254074.json, Rows added: 124, Total rows: 31744
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254075.json, Rows added: 124, Total rows: 31868
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254076.json, Rows added: 124, Total rows: 31992
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254077.json, Rows added: 124, Total rows: 32116
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254078.json, Rows added: 124, Total rows: 32240
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254079.json, Rows added: 124, Total rows: 32364
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254080.json, Rows added: 124, Total rows: 32488
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254081.json, Rows added: 124, Total rows: 32612
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254082.json, Rows added: 124, Total rows: 32736
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254083.json, Rows added: 124, Total rows: 32860
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254084.json, Rows added: 124, Total rows: 32984
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254085.json, Rows added: 124, Total rows: 33108
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254086.json, Rows added: 124, Total rows: 33232
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254087.json, Rows added: 124, Total rows: 33356
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254088.json, Rows added: 124, Total rows: 33480
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254089.json, Rows added: 124, Total rows: 33604
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254090.json, Rows added: 124, Total rows: 33728
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254091.json, Rows added: 124, Total rows: 33852
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254092.json, Rows added: 124, Total rows: 33976
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254093.json, Rows added: 124, Total rows: 34100
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254094.json, Rows added: 124, Total rows: 34224
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254095.json, Rows added: 124, Total rows: 34348
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254096.json, Rows added: 124, Total rows: 34472
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254097.json, Rows added: 124, Total rows: 34596
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254098.json, Rows added: 124, Total rows: 34720
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254099.json, Rows added: 124, Total rows: 34844
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254100.json, Rows added: 124, Total rows: 34968
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254101.json, Rows added: 124, Total rows: 35092
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254102.json, Rows added: 124, Total rows: 35216
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254103.json, Rows added: 124, Total rows: 35340
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254104.json, Rows added: 124, Total rows: 35464
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254105.json, Rows added: 124, Total rows: 35588
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254106.json, Rows added: 124, Total rows: 35712
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254107.json, Rows added: 124, Total rows: 35836
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254108.json, Rows added: 124, Total rows: 35960
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254109.json, Rows added: 124, Total rows: 36084
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254110.json, Rows added: 124, Total rows: 36208
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254111.json, Rows added: 124, Total rows: 36332
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254112.json, Rows added: 124, Total rows: 36456
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254113.json, Rows added: 124, Total rows: 36580
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254114.json, Rows added: 124, Total rows: 36704
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254115.json, Rows added: 124, Total rows: 36828
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254116.json, Rows added: 124, Total rows: 36952
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1254117.json, Rows added: 124, Total rows: 37076
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304047.json, Rows added: 124, Total rows: 37200
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304048.json, Rows added: 124, Total rows: 37324
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304049.json, Rows added: 124, Total rows: 37448
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304050.json, Rows added: 124, Total rows: 37572
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304051.json, Rows added: 124, Total rows: 37696
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304052.json, Rows added: 124, Total rows: 37820
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304053.json, Rows added: 124, Total rows: 37944
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304054.json, Rows added: 124, Total rows: 38068
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304055.json, Rows added: 124, Total rows: 38192
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304056.json, Rows added: 124, Total rows: 38316
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304057.json, Rows added: 124, Total rows: 38440
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304058.json, Rows added: 124, Total rows: 38564
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304059.json, Rows added: 124, Total rows: 38688
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304060.json, Rows added: 124, Total rows: 38812
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304061.json, Rows added: 124, Total rows: 38936
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304062.json, Rows added: 124, Total rows: 39060
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304063.json, Rows added: 124, Total rows: 39184
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304064.json, Rows added: 124, Total rows: 39308
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304065.json, Rows added: 124, Total rows: 39432
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304066.json, Rows added: 124, Total rows: 39556
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304067.json, Rows added: 124, Total rows: 39680
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304068.json, Rows added: 124, Total rows: 39804
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304069.json, Rows added: 124, Total rows: 39928
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304070.json, Rows added: 124, Total rows: 40052
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304071.json, Rows added: 124, Total rows: 40176
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304072.json, Rows added: 124, Total rows: 40300
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304073.json, Rows added: 124, Total rows: 40424
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304074.json, Rows added: 124, Total rows: 40548
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304075.json, Rows added: 124, Total rows: 40672
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304076.json, Rows added: 124, Total rows: 40796
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304077.json, Rows added: 124, Total rows: 40920
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304078.json, Rows added: 124, Total rows: 41044
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304079.json, Rows added: 124, Total rows: 41168
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304080.json, Rows added: 124, Total rows: 41292
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304081.json, Rows added: 124, Total rows: 41416
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304082.json, Rows added: 124, Total rows: 41540
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304083.json, Rows added: 124, Total rows: 41664
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304084.json, Rows added: 124, Total rows: 41788
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304085.json, Rows added: 124, Total rows: 41912
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304086.json, Rows added: 124, Total rows: 42036
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304087.json, Rows added: 124, Total rows: 42160
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304088.json, Rows added: 124, Total rows: 42284
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304089.json, Rows added: 124, Total rows: 42408
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304090.json, Rows added: 124, Total rows: 42532
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304091.json, Rows added: 124, Total rows: 42656
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304092.json, Rows added: 124, Total rows: 42780
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304093.json, Rows added: 124, Total rows: 42904
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304094.json, Rows added: 124, Total rows: 43028
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304095.json, Rows added: 124, Total rows: 43152
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304096.json, Rows added: 124, Total rows: 43276
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304097.json, Rows added: 124, Total rows: 43400
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304098.json, Rows added: 124, Total rows: 43524
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304099.json, Rows added: 124, Total rows: 43648
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304100.json, Rows added: 124, Total rows: 43772
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304101.json, Rows added: 124, Total rows: 43896
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304102.json, Rows added: 124, Total rows: 44020
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304103.json, Rows added: 124, Total rows: 44144
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304104.json, Rows added: 124, Total rows: 44268
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304105.json, Rows added: 124, Total rows: 44392
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304106.json, Rows added: 124, Total rows: 44516
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304107.json, Rows added: 124, Total rows: 44640
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304108.json, Rows added: 124, Total rows: 44764
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304109.json, Rows added: 124, Total rows: 44888
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304110.json, Rows added: 124, Total rows: 45012
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304111.json, Rows added: 124, Total rows: 45136
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304112.json, Rows added: 124, Total rows: 45260
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304113.json, Rows added: 124, Total rows: 45384
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304114.json, Rows added: 124, Total rows: 45508
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304115.json, Rows added: 124, Total rows: 45632
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1304116.json, Rows added: 124, Total rows: 45756
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1312197.json, Rows added: 124, Total rows: 45880
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1312198.json, Rows added: 124, Total rows: 46004
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1312199.json, Rows added: 124, Total rows: 46128
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1312200.json, Rows added: 124, Total rows: 46252
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359475.json, Rows added: 124, Total rows: 46376
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359476.json, Rows added: 124, Total rows: 46500
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359477.json, Rows added: 124, Total rows: 46624
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359478.json, Rows added: 124, Total rows: 46748
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359479.json, Rows added: 124, Total rows: 46872
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359480.json, Rows added: 124, Total rows: 46996
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359481.json, Rows added: 124, Total rows: 47120
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359482.json, Rows added: 124, Total rows: 47244
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359483.json, Rows added: 124, Total rows: 47368
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359484.json, Rows added: 124, Total rows: 47492
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359485.json, Rows added: 124, Total rows: 47616
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359486.json, Rows added: 124, Total rows: 47740
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359487.json, Rows added: 124, Total rows: 47864
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359488.json, Rows added: 124, Total rows: 47988
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359489.json, Rows added: 124, Total rows: 48112
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359490.json, Rows added: 124, Total rows: 48236
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359491.json, Rows added: 124, Total rows: 48360
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359492.json, Rows added: 124, Total rows: 48484
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359493.json, Rows added: 124, Total rows: 48608
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359494.json, Rows added: 124, Total rows: 48732
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359495.json, Rows added: 124, Total rows: 48856
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359496.json, Rows added: 124, Total rows: 48980
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359497.json, Rows added: 124, Total rows: 49104
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359498.json, Rows added: 124, Total rows: 49228
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359499.json, Rows added: 124, Total rows: 49352
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359500.json, Rows added: 124, Total rows: 49476
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359501.json, Rows added: 124, Total rows: 49600
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359502.json, Rows added: 124, Total rows: 49724
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359503.json, Rows added: 124, Total rows: 49848
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359504.json, Rows added: 124, Total rows: 49972
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359505.json, Rows added: 124, Total rows: 50096
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359506.json, Rows added: 124, Total rows: 50220
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359507.json, Rows added: 124, Total rows: 50344
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359508.json, Rows added: 124, Total rows: 50468
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359509.json, Rows added: 124, Total rows: 50592
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359510.json, Rows added: 124, Total rows: 50716
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359511.json, Rows added: 124, Total rows: 50840
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359512.json, Rows added: 124, Total rows: 50964
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359513.json, Rows added: 124, Total rows: 51088
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359514.json, Rows added: 124, Total rows: 51212
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359515.json, Rows added: 124, Total rows: 51336
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359516.json, Rows added: 124, Total rows: 51460
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359517.json, Rows added: 124, Total rows: 51584
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359518.json, Rows added: 124, Total rows: 51708
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359520.json, Rows added: 124, Total rows: 51832
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359521.json, Rows added: 124, Total rows: 51956
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359522.json, Rows added: 124, Total rows: 52080
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359523.json, Rows added: 124, Total rows: 52204
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359524.json, Rows added: 124, Total rows: 52328
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359525.json, Rows added: 124, Total rows: 52452
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359526.json, Rows added: 124, Total rows: 52576
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359527.json, Rows added: 124, Total rows: 52700
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359528.json, Rows added: 124, Total rows: 52824
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359529.json, Rows added: 124, Total rows: 52948
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359530.json, Rows added: 124, Total rows: 53072
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359531.json, Rows added: 124, Total rows: 53196
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359532.json, Rows added: 124, Total rows: 53320
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359533.json, Rows added: 124, Total rows: 53444
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359534.json, Rows added: 124, Total rows: 53568
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359535.json, Rows added: 124, Total rows: 53692
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359536.json, Rows added: 124, Total rows: 53816
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359537.json, Rows added: 124, Total rows: 53940
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359538.json, Rows added: 124, Total rows: 54064
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359539.json, Rows added: 124, Total rows: 54188
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359540.json, Rows added: 124, Total rows: 54312
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359541.json, Rows added: 124, Total rows: 54436
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359542.json, Rows added: 124, Total rows: 54560
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359543.json, Rows added: 124, Total rows: 54684
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1359544.json, Rows added: 124, Total rows: 54808
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1370350.json, Rows added: 124, Total rows: 54932
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1370351.json, Rows added: 124, Total rows: 55056
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1370352.json, Rows added: 124, Total rows: 55180
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1370353.json, Rows added: 124, Total rows: 55304
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422119.json, Rows added: 124, Total rows: 55428
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422120.json, Rows added: 124, Total rows: 55552
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422121.json, Rows added: 124, Total rows: 55676
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422122.json, Rows added: 124, Total rows: 55800
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422123.json, Rows added: 124, Total rows: 55924
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422124.json, Rows added: 124, Total rows: 56048
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422125.json, Rows added: 124, Total rows: 56172
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422126.json, Rows added: 124, Total rows: 56296
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422127.json, Rows added: 124, Total rows: 56420
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422128.json, Rows added: 124, Total rows: 56544
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422129.json, Rows added: 124, Total rows: 56668
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422130.json, Rows added: 124, Total rows: 56792
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422131.json, Rows added: 124, Total rows: 56916
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422132.json, Rows added: 124, Total rows: 57040
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422133.json, Rows added: 124, Total rows: 57164
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422134.json, Rows added: 124, Total rows: 57288
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422135.json, Rows added: 124, Total rows: 57412
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422136.json, Rows added: 124, Total rows: 57536
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422137.json, Rows added: 124, Total rows: 57660
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422138.json, Rows added: 124, Total rows: 57784
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1422139.json, Rows added: 124, Total rows: 57908
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426260.json, Rows added: 124, Total rows: 58032
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426261.json, Rows added: 124, Total rows: 58156
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426262.json, Rows added: 124, Total rows: 58280
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426263.json, Rows added: 124, Total rows: 58404
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426264.json, Rows added: 124, Total rows: 58528
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426265.json, Rows added: 124, Total rows: 58652
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426266.json, Rows added: 124, Total rows: 58776
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426267.json, Rows added: 124, Total rows: 58900
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426268.json, Rows added: 124, Total rows: 59024
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426269.json, Rows added: 124, Total rows: 59148
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426270.json, Rows added: 124, Total rows: 59272
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426271.json, Rows added: 124, Total rows: 59396
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426272.json, Rows added: 124, Total rows: 59520
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426273.json, Rows added: 124, Total rows: 59644
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426274.json, Rows added: 124, Total rows: 59768
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426275.json, Rows added: 124, Total rows: 59892
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426276.json, Rows added: 124, Total rows: 60016
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426277.json, Rows added: 124, Total rows: 60140
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426278.json, Rows added: 124, Total rows: 60264
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426279.json, Rows added: 124, Total rows: 60388
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426280.json, Rows added: 124, Total rows: 60512
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426281.json, Rows added: 124, Total rows: 60636
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426282.json, Rows added: 124, Total rows: 60760
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426283.json, Rows added: 124, Total rows: 60884
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426284.json, Rows added: 124, Total rows: 61008
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426285.json, Rows added: 124, Total rows: 61132
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426286.json, Rows added: 124, Total rows: 61256
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426287.json, Rows added: 124, Total rows: 61380
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426288.json, Rows added: 124, Total rows: 61504
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426289.json, Rows added: 124, Total rows: 61628
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426290.json, Rows added: 124, Total rows: 61752
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426291.json, Rows added: 124, Total rows: 61876
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426292.json, Rows added: 124, Total rows: 62000
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426293.json, Rows added: 124, Total rows: 62124
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426294.json, Rows added: 124, Total rows: 62248
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426295.json, Rows added: 124, Total rows: 62372
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426296.json, Rows added: 124, Total rows: 62496
# File: C:\Users\HP\Downloads\ipl_male_json (1)\1426297.json, Rows added: 124, Total rows: 62620
# ...
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729299.json, Rows added: 124, Total rows: 114700
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729301.json, Rows added: 124, Total rows: 114824
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729303.json, Rows added: 124, Total rows: 114948
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729305.json, Rows added: 124, Total rows: 115072
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729307.json, Rows added: 124, Total rows: 115196
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729309.json, Rows added: 124, Total rows: 115320
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729311.json, Rows added: 124, Total rows: 115444
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729313.json, Rows added: 124, Total rows: 115568
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729315.json, Rows added: 124, Total rows: 115692
# File: C:\Users\HP\Downloads\ipl_male_json (1)\729317.json, Rows added: 124, Total rows: 115816
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733971.json, Rows added: 124, Total rows: 115940
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733973.json, Rows added: 124, Total rows: 116064
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733975.json, Rows added: 124, Total rows: 116188
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733977.json, Rows added: 124, Total rows: 116312
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733979.json, Rows added: 124, Total rows: 116436
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733981.json, Rows added: 124, Total rows: 116560
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733983.json, Rows added: 124, Total rows: 116684
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733985.json, Rows added: 124, Total rows: 116808
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733987.json, Rows added: 124, Total rows: 116932
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733989.json, Rows added: 124, Total rows: 117056
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733991.json, Rows added: 124, Total rows: 117180
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733993.json, Rows added: 124, Total rows: 117304
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733995.json, Rows added: 124, Total rows: 117428
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733997.json, Rows added: 124, Total rows: 117552
# File: C:\Users\HP\Downloads\ipl_male_json (1)\733999.json, Rows added: 124, Total rows: 117676
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734001.json, Rows added: 124, Total rows: 117800
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734003.json, Rows added: 124, Total rows: 117924
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734005.json, Rows added: 124, Total rows: 118048
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734007.json, Rows added: 124, Total rows: 118172
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734009.json, Rows added: 124, Total rows: 118296
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734011.json, Rows added: 124, Total rows: 118420
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734013.json, Rows added: 124, Total rows: 118544
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734015.json, Rows added: 124, Total rows: 118668
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734017.json, Rows added: 124, Total rows: 118792
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734019.json, Rows added: 124, Total rows: 118916
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734021.json, Rows added: 124, Total rows: 119040
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734023.json, Rows added: 124, Total rows: 119164
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734025.json, Rows added: 124, Total rows: 119288
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734027.json, Rows added: 124, Total rows: 119412
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734029.json, Rows added: 124, Total rows: 119536
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734031.json, Rows added: 124, Total rows: 119660
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734033.json, Rows added: 124, Total rows: 119784
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734035.json, Rows added: 124, Total rows: 119908
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734037.json, Rows added: 124, Total rows: 120032
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734039.json, Rows added: 124, Total rows: 120156
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734041.json, Rows added: 124, Total rows: 120280
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734043.json, Rows added: 124, Total rows: 120404
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734045.json, Rows added: 124, Total rows: 120528
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734047.json, Rows added: 124, Total rows: 120652
# File: C:\Users\HP\Downloads\ipl_male_json (1)\734049.json, Rows added: 124, Total rows: 120776
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829705.json, Rows added: 124, Total rows: 120900
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829707.json, Rows added: 124, Total rows: 121024
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829709.json, Rows added: 124, Total rows: 121148
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829711.json, Rows added: 124, Total rows: 121272
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829713.json, Rows added: 124, Total rows: 121396
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829715.json, Rows added: 124, Total rows: 121520
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829717.json, Rows added: 124, Total rows: 121644
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829719.json, Rows added: 124, Total rows: 121768
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829721.json, Rows added: 124, Total rows: 121892
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829723.json, Rows added: 124, Total rows: 122016
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829725.json, Rows added: 124, Total rows: 122140
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829727.json, Rows added: 124, Total rows: 122264
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829729.json, Rows added: 124, Total rows: 122388
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829731.json, Rows added: 124, Total rows: 122512
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829733.json, Rows added: 124, Total rows: 122636
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829735.json, Rows added: 124, Total rows: 122760
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829737.json, Rows added: 124, Total rows: 122884
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829739.json, Rows added: 124, Total rows: 123008
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829741.json, Rows added: 124, Total rows: 123132
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829743.json, Rows added: 124, Total rows: 123256
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829745.json, Rows added: 124, Total rows: 123380
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829747.json, Rows added: 124, Total rows: 123504
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829749.json, Rows added: 124, Total rows: 123628
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829751.json, Rows added: 124, Total rows: 123752
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829753.json, Rows added: 124, Total rows: 123876
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829757.json, Rows added: 124, Total rows: 124000
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829759.json, Rows added: 124, Total rows: 124124
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829761.json, Rows added: 124, Total rows: 124248
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829765.json, Rows added: 124, Total rows: 124372
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829767.json, Rows added: 124, Total rows: 124496
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829769.json, Rows added: 124, Total rows: 124620
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829771.json, Rows added: 124, Total rows: 124744
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829773.json, Rows added: 124, Total rows: 124868
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829775.json, Rows added: 124, Total rows: 124992
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829777.json, Rows added: 124, Total rows: 125116
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829779.json, Rows added: 124, Total rows: 125240
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829781.json, Rows added: 124, Total rows: 125364
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829783.json, Rows added: 124, Total rows: 125488
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829785.json, Rows added: 124, Total rows: 125612
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829787.json, Rows added: 124, Total rows: 125736
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829789.json, Rows added: 124, Total rows: 125860
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829791.json, Rows added: 124, Total rows: 125984
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829793.json, Rows added: 124, Total rows: 126108
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829795.json, Rows added: 124, Total rows: 126232
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829797.json, Rows added: 124, Total rows: 126356
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829799.json, Rows added: 124, Total rows: 126480
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829801.json, Rows added: 124, Total rows: 126604
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829803.json, Rows added: 124, Total rows: 126728
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829805.json, Rows added: 124, Total rows: 126852
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829807.json, Rows added: 124, Total rows: 126976
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829809.json, Rows added: 124, Total rows: 127100
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829811.json, Rows added: 124, Total rows: 127224
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829813.json, Rows added: 124, Total rows: 127348
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829815.json, Rows added: 124, Total rows: 127472
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829817.json, Rows added: 124, Total rows: 127596
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829819.json, Rows added: 124, Total rows: 127720
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829821.json, Rows added: 124, Total rows: 127844
# File: C:\Users\HP\Downloads\ipl_male_json (1)\829823.json, Rows added: 124, Total rows: 127968
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980901.json, Rows added: 124, Total rows: 128092
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980903.json, Rows added: 124, Total rows: 128216
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980905.json, Rows added: 124, Total rows: 128340
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980907.json, Rows added: 124, Total rows: 128464
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980909.json, Rows added: 124, Total rows: 128588
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980911.json, Rows added: 124, Total rows: 128712
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980913.json, Rows added: 124, Total rows: 128836
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980915.json, Rows added: 124, Total rows: 128960
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980917.json, Rows added: 124, Total rows: 129084
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980919.json, Rows added: 124, Total rows: 129208
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980921.json, Rows added: 124, Total rows: 129332
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980923.json, Rows added: 124, Total rows: 129456
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980925.json, Rows added: 124, Total rows: 129580
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980927.json, Rows added: 124, Total rows: 129704
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980929.json, Rows added: 124, Total rows: 129828
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980931.json, Rows added: 124, Total rows: 129952
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980933.json, Rows added: 124, Total rows: 130076
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980935.json, Rows added: 124, Total rows: 130200
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980937.json, Rows added: 124, Total rows: 130324
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980939.json, Rows added: 124, Total rows: 130448
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980941.json, Rows added: 124, Total rows: 130572
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980943.json, Rows added: 124, Total rows: 130696
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980945.json, Rows added: 124, Total rows: 130820
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980947.json, Rows added: 124, Total rows: 130944
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980949.json, Rows added: 124, Total rows: 131068
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980951.json, Rows added: 124, Total rows: 131192
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980953.json, Rows added: 124, Total rows: 131316
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980955.json, Rows added: 124, Total rows: 131440
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980957.json, Rows added: 124, Total rows: 131564
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980959.json, Rows added: 124, Total rows: 131688
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980961.json, Rows added: 124, Total rows: 131812
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980963.json, Rows added: 124, Total rows: 131936
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980965.json, Rows added: 124, Total rows: 132060
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980967.json, Rows added: 124, Total rows: 132184
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980969.json, Rows added: 124, Total rows: 132308
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980971.json, Rows added: 124, Total rows: 132432
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980973.json, Rows added: 124, Total rows: 132556
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980975.json, Rows added: 124, Total rows: 132680
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980977.json, Rows added: 124, Total rows: 132804
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980979.json, Rows added: 124, Total rows: 132928
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980981.json, Rows added: 124, Total rows: 133052
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980983.json, Rows added: 124, Total rows: 133176
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980985.json, Rows added: 124, Total rows: 133300
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980987.json, Rows added: 124, Total rows: 133424
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980989.json, Rows added: 124, Total rows: 133548
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980991.json, Rows added: 124, Total rows: 133672
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980993.json, Rows added: 124, Total rows: 133796
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980995.json, Rows added: 124, Total rows: 133920
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980997.json, Rows added: 124, Total rows: 134044
# File: C:\Users\HP\Downloads\ipl_male_json (1)\980999.json, Rows added: 124, Total rows: 134168
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981001.json, Rows added: 124, Total rows: 134292
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981003.json, Rows added: 124, Total rows: 134416
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981005.json, Rows added: 124, Total rows: 134540
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981007.json, Rows added: 124, Total rows: 134664
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981009.json, Rows added: 124, Total rows: 134788
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981011.json, Rows added: 124, Total rows: 134912
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981013.json, Rows added: 124, Total rows: 135036
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981015.json, Rows added: 124, Total rows: 135160
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981017.json, Rows added: 124, Total rows: 135284
# File: C:\Users\HP\Downloads\ipl_male_json (1)\981019.json, Rows added: 124, Total rows: 135408

# %%
print("DataFrame shape:", all_matches_df.shape)
# Out:
# DataFrame shape: (261149, 10)

# %%
all_matches_df.shape
# Out:
# (261149, 10)

# %%
all_matches_df['batting_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Delhi Capitals',
#        'Punjab Kings', 'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru', 'Deccan Chargers', 'Pune Warriors',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'], dtype=object)

# %%
all_matches_df['bowling_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Delhi Capitals',
#        'Punjab Kings', 'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],
#       dtype=object)

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bengaluru',
    'Kolkata Knight Riders',
    'Punjab Kings',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals'
]

# %%
all_matches_df['batting_team'] = all_matches_df['batting_team'].str.replace('Delhi Daredevils','Delhi Capitals')
all_matches_df['bowling_team'] = all_matches_df['bowling_team'].str.replace('Delhi Daredevils','Delhi Capitals')

all_matches_df['batting_team'] = all_matches_df['batting_team'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
all_matches_df['bowling_team'] = all_matches_df['bowling_team'].str.replace('Deccan Chargers','Sunrisers Hyderabad')


all_matches_df['batting_team'] = all_matches_df['batting_team'].str.replace('Kings XI Punjab','Punjab Kings')
all_matches_df['bowling_team'] = all_matches_df['bowling_team'].str.replace('Kings XI Punjab','Punjab Kings')


all_matches_df['batting_team'] = all_matches_df['batting_team'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')
all_matches_df['bowling_team'] = all_matches_df['bowling_team'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')

# %%
all_matches_df = all_matches_df[all_matches_df['batting_team'].isin(teams)]
all_matches_df = all_matches_df[all_matches_df['bowling_team'].isin(teams)]

# %%
all_matches_df.shape
# Out:
# (238432, 10)

# %%
all_matches_df['batting_team'].unique()
# Out:
# array(['Royal Challengers Bengaluru', 'Delhi Capitals', 'Mumbai Indians',
#        'Punjab Kings', 'Kolkata Knight Riders', 'Sunrisers Hyderabad',
#        'Chennai Super Kings', 'Rajasthan Royals'], dtype=object)

# %%
all_matches_df['result'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
final_df = all_matches_df[['batting_team','bowling_team','runs_left','balls_left','wickets_left','target','crr','rrr','result']]

# %%
final_df.head()
# Out:
#                   batting_team         bowling_team  runs_left  balls_left  \
# 0  Royal Challengers Bengaluru  Sunrisers Hyderabad        207         119
# 1  Royal Challengers Bengaluru  Sunrisers Hyderabad        207         118
# 2  Royal Challengers Bengaluru  Sunrisers Hyderabad        207         117
# 3  Royal Challengers Bengaluru  Sunrisers Hyderabad        205         116
# 4  Royal Challengers Bengaluru  Sunrisers Hyderabad        201         115
#
#    wickets_left  target  crr        rrr  result
# 0            10     208  6.0  10.436975       0
# 1            10     208  3.0  10.525424       0
# 2            10     208  2.0  10.615385       0
# 3            10     208  4.5  10.603448       0
# 4            10     208  8.4  10.486957       0

# %%
final_df.shape
# Out:
# (238432, 9)

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#                        batting_team         bowling_team  runs_left  \
# 219652  Royal Challengers Bengaluru  Sunrisers Hyderabad        141
#
#         balls_left  wickets_left  target       crr        rrr  result
# 219652          76            10     209  9.272727  11.131579       0

# %%
final_df.dropna(inplace=True)

# %%
final_df.shape
# Out:
# (238432, 9)

# %%
final_df = final_df[final_df['balls_left'] != 0]

# %%
final_df.shape
# Out:
# (236839, 9)

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                        batting_team           bowling_team  runs_left  \
# 137498  Royal Challengers Bengaluru    Sunrisers Hyderabad         45
# 241524  Royal Challengers Bengaluru    Sunrisers Hyderabad         57
# 32848                Mumbai Indians    Chennai Super Kings         73
# 105503          Chennai Super Kings         Mumbai Indians        145
# 59928         Kolkata Knight Riders    Sunrisers Hyderabad         63
# ...                             ...                    ...        ...
# 29852           Sunrisers Hyderabad         Delhi Capitals         52
# 202777  Royal Challengers Bengaluru    Sunrisers Hyderabad        154
# 225576  Royal Challengers Bengaluru    Sunrisers Hyderabad        190
# 20661                  Punjab Kings         Delhi Capitals         74
# 66713           Sunrisers Hyderabad  Kolkata Knight Riders         20
#
#         balls_left  wickets_left  target        crr        rrr
# 137498          18             6     209   9.647059  15.000000
# 241524          28             7     209   9.913043  12.214286
# 32848           45             6     157   6.720000   9.733333
# 105503         108             7     149   2.000000   8.055556
# 59928           90             9     114  10.200000   4.200000
# ...            ...           ...     ...        ...        ...
# 29852           29             6     160   7.120879  10.758621
# 202777          87            10     209  10.000000  10.620690
# 225576         104            10     209   7.125000  10.961538
# 20661           35             5     158   5.929412  12.685714
# 66713           50             8     102   7.028571   2.400000
#
# [189471 rows x 8 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9003968924168215

# %%
pipe.predict_proba(X_test)[11200]
# Out:
# array([0.0602164, 0.9397836])

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bengaluru',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals']

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
def find_closest_scenarios(final_df, input_data, num_scenarios=5):
    # Extract input features
    runs_left, balls_left, wickets_left, crr, rrr = input_data

    # Calculate distance from each row in DataFrame to the input data
    final_df['distance'] = np.sqrt(
        (final_df['runs_left'] - runs_left)**2 +
        (final_df['balls_left'] - balls_left)**2 +
        (final_df['wickets_left'] - wickets_left)**2 +
        (final_df['crr'] - crr)**2 +
        (final_df['rrr'] - rrr)**2
    )

    # Sort by distance and select the closest scenarios
    closest_scenarios_df = all_matches_df.nsmallest(num_scenarios, 'distance')
    
    # Convert the results to a list of dictionaries
    closest_scenarios = closest_scenarios_df.to_dict(orient='records')
    
    # If fewer than num_scenarios are found, repeat entries or add placeholders
    while len(closest_scenarios) < num_scenarios:
        closest_scenarios.append({
            'batting_team': 'N/A',
            'bowling_team': 'N/A',
            'runs_left': None,
            'balls_left': None,
            'wickets_left': None,
            'total_runs': None,
            'target': None,
            'crr': None,
            'rrr': None,
            'result': None,
            'distance': None
        })

    return closest_scenarios

# %%
import numpy as np

def find_closest_scenarios(final_df, input_data, num_scenarios=5):
    # Extract input features
    runs_left, balls_left, wickets_left, crr, rrr = input_data

    # Calculate distance from each row in DataFrame to the input data
    final_df['distance'] = np.sqrt(
        (final_df['runs_left'] - runs_left)**2 +
        (final_df['balls_left'] - balls_left)**2 +
        (final_df['wickets_left'] - wickets_left)**2 +
        (final_df['crr'] - crr)**2 +
        (final_df['rrr'] - rrr)**2
    )

    # Sort by distance and select the closest scenarios
    closest_scenarios_df = final_df.nsmallest(num_scenarios, 'distance')

    # Format each scenario for output
    output = []
    for i, row in closest_scenarios_df.iterrows():
        scenario = (f"{row.get('batting_team', 'N/A')}, {row.get('bowling_team', 'N/A')}, "
                    f"Team Batting First: {row.get('batting_team', 'N/A')},\n"
                    f"Second Innings \n"
                    f"Run Scored: {row.get('total_runs', 'N/A')}, Wicket Fallen: {10 - row['wickets_left']}, "
                    f"Overs Completed: {20 - (row['balls_left'] // 6)}, "
                    f"Runs still required to win: {row['runs_left']},\n"
                    f"Winning Team: {row.get('batting_team', 'N/A') if row['result'] == 1 else row.get('bowling_team', 'N/A')}"
                    f"\n")
        output.append(scenario)

    # Ensure there are at least `num_scenarios` entries by adding placeholders if needed
    while len(output) < num_scenarios:
        output.append("Scenario N/A: Placeholder data")

    return "\n".join(output)

# Test input
input_data = [52, 30, 4, 7.1, 8.4]

# Call the function to find closest scenarios
formatted_output = find_closest_scenarios(all_matches_df, input_data, num_scenarios=5)

print(formatted_output)
# Out:
# Delhi Capitals, Mumbai Indians, Team Batting First: Delhi Capitals,
# Second Innings
# Run Scored: 162, Wicket Fallen: 5, Overs Completed: 15, Runs still required to win: 52,
# Winning Team: Mumbai Indians
#
# Delhi Capitals, Chennai Super Kings, Team Batting First: Delhi Capitals,
# Second Innings
# Run Scored: 150, Wicket Fallen: 5, Overs Completed: 15, Runs still required to win: 52,
# Winning Team: Chennai Super Kings
#
# Punjab Kings, Sunrisers Hyderabad, Team Batting First: Punjab Kings,
# Second Innings
# Run Scored: 168, Wicket Fallen: 5, Overs Completed: 15, Runs still required to win: 52,
# Winning Team: Punjab Kings
#
# Rajasthan Royals, Delhi Capitals, Team Batting First: Rajasthan Royals,
# Second Innings
# Run Scored: 143, Wicket Fallen: 5, Overs Completed: 15, Runs still required to win: 52,
# Winning Team: Rajasthan Royals
#
# Punjab Kings, Royal Challengers Bengaluru, Team Batting First: Punjab Kings,
# Second Innings
# Run Scored: 174, Wicket Fallen: 7, Overs Completed: 15, Runs still required to win: 52,
# Winning Team: Royal Challengers Bengaluru

# %%
import pandas as pd

# Assuming all_matches_df is your DataFrame
all_matches_df.to_csv('all_matches.csv', index=False)
